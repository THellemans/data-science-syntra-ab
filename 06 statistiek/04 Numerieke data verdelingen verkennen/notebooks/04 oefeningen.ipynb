# %%
import pandas as pd
import os
import gzip

# %% [markdown]
# ## File locations

# %%
loc_file_sp500_sectors = os.path.join('..', 'data', 'sp500_sectors.csv')
loc_file_sp500_data = os.path.join('..', 'data', 'sp500_data.csv')

# %% [markdown]
# ## Oefening 1; vele correlaties samen plotten

# %%
df_sp500 = pd.read_csv(loc_file_sp500_data)

# %%
df_sp500
# Out:
#       Unnamed: 0        ADS        CA      MSFT       RHT      CTSH       CSC  \
# 0     1993-01-29   0.000000  0.060124 -0.022100  0.000000  0.000000  0.018897
# 1     1993-02-01   0.000000 -0.180389  0.027621  0.000000  0.000000  0.018889
# 2     1993-02-02   0.000000 -0.120257  0.035900  0.000000  0.000000 -0.075573
# 3     1993-02-03   0.000000  0.060124 -0.024857  0.000000  0.000000 -0.151128
# 4     1993-02-04   0.000000 -0.360770 -0.060757  0.000000  0.000000  0.113350
# ...          ...        ...       ...       ...       ...       ...       ...
# 5642  2015-06-25   0.019989 -0.529999 -0.379997  0.080002  0.350003 -0.580002
# 5643  2015-06-26  -1.299988 -0.330000 -0.390004 -1.820000  0.190003  0.330002
# 5644  2015-06-29 -10.299988 -0.410000 -0.670002 -1.250000 -1.919998 -0.510002
# 5645  2015-06-30  -2.109986 -0.049999 -0.559997 -0.099999 -0.689999 -0.610001
# 5646  2015-07-01  -1.210022  0.020000 -0.009998  0.869995  0.329998 -0.190003
#
# ...

# %%
type(sp500_data)
# Out:
# bytes

# %%
df_sp500 = pd.read_csv(loc_file_sp500)
etfs = df[]

# %%
df_sp500
# Out:
#                      sector sector_label  \
# 0    information_technology   Technology
# 1    information_technology   Technology
# 2    information_technology   Technology
# 3    information_technology   Technology
# 4    information_technology   Technology
# ..                      ...          ...
# 512             health_care  Health Care
# 513             health_care  Health Care
# 514             health_care  Health Care
# 515             health_care  Health Care
# 516             health_care  Health Care
#
#                                 sub_sector symbol
# 0    data_processing_&_outsourced_services    ADS
# 1                         systems_software     CA
# 2                         systems_software   MSFT
# 3                         systems_software    RHT
# 4                 it_consulting_&_services   CTSH
# ..                                     ...    ...
# 512                          biotechnology   CELG
# 513                          biotechnology   GILD
# ...
